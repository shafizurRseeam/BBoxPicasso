# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
import os
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\machine_learning\attack1\laplace\200\merged_laplace_0.1_encoded_200.csv')
df
# Out:
#        longitude   latitude  identifier  perturbed_latitude  \
# 0     -77.680333  43.083838         1.0           43.083840
# 1     -77.680991  43.083803         1.0           43.083827
# 2     -77.681017  43.083802         1.0           43.083831
# 3     -77.681042  43.083802         1.0           43.083767
# 4     -77.681090  43.083802         1.0           43.083803
# ...          ...        ...         ...                 ...
# 55420 -77.680445  43.083879        46.0           43.083866
# 55421 -77.680442  43.083868        46.0           43.083876
# 55422 -77.680441  43.083863        46.0           43.083831
# 55423 -77.680442  43.083860        46.0           43.083824
# 55424 -77.680442  43.083850        46.0           43.083863
#
#        perturbed_longitude  lat_bin  lon_bin  location_id
# 0               -77.680344       97       66        19467
# 1               -77.681023       97       62        19463
# 2               -77.680987       97       62        19463
# ...

# %%
def train_validation_split(data):

    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']

    #scaler = StandardScaler()
    #features_scaled = scaler.fit_transform(features)
    #features_scaled_df = pd.Dataframe(features_scaled, columns=['perturbed_latitude', 'perturbed_longitude'])

    X_train, X_test, y_train, y_test, identifiers_train, identifiers_test = train_test_split(
                                            features, labels, data['identifier'], test_size=0.2
                                            )

    return X_train, X_test, y_train, y_test, identifiers_train, identifiers_test

# %%
 X_train, X_test, y_train, y_test, identifiers_train, identifiers_test = train_validation_split(df)

# %%
X_train
# Out:
#        perturbed_latitude  perturbed_longitude
# 43751           43.083972           -77.680050
# 18652           43.085138           -77.678932
# 31114           43.084331           -77.675604
# 5269            43.092672           -77.661727
# 35206           43.083904           -77.679032
# ...                   ...                  ...
# 44544           43.083682           -77.680406
# 54798           43.084006           -77.680384
# 33049           43.084229           -77.674296
# 16017           43.085167           -77.679020
# 6022            43.091350           -77.679831
#
# [44340 rows x 2 columns]

# %%
y_train
# Out:
# 43751    19668
# 18652    21074
# 31114    20091
# 5269     29561
# 35206    19673
#          ...
# 44544    19467
# 54798    19666
# 33049    20097
# 16017    21073
# 6022     27869
# Name: location_id, Length: 44340, dtype: int64

# %%
identifiers_train
# Out:
# 43751    36.0
# 18652    20.0
# 31114    26.0
# 5269      6.0
# 35206    33.0
#          ...
# 44544    37.0
# 54798    46.0
# 33049    31.0
# 16017    19.0
# 6022      6.0
# Name: identifier, Length: 44340, dtype: float64

# %%
def knn_fit(X_train, y_train, strategy_ln = True):
    
    if strategy_ln:
        
        k = round(np.log(len(X_train)))
    else:
        k = round(np.log10(len(X_train)))
    print(k)    

    knn = KNeighborsClassifier(n_neighbors=6)    

    knn.fit(X_train, y_train)

    return knn

# %%
k=knn_fit(X_train, y_train, strategy_ln = True)
k
# Out:
# 11
# KNeighborsClassifier(n_neighbors=6)

# %%
import math

# %%
def knn_fit(data):
        
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']

    #scaler = StandardScaler()
    #features_scaled = scaler.fit_transform(features)
    #features_scaled_df = pd.Dataframe(features_scaled, columns=['perturbed_latitude', 'perturbed_longitude'])

    X_train, X_test, y_train, y_test = train_test_split(
                                            features, labels,  test_size=0.8, random_state = 42
                                            )

    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')

    knn.fit(X_train, y_train)
    
    #predictions = knn.predict(X_test)


    probabilities = knn.predict_proba(X_test)

    # Get the indices of the max probabilities
    predicted_indices = np.argmax(probabilities, axis=1)
    # Map indices to actual class labels
    predicted_labels_corrected = knn.classes_[predicted_indices]
    
    #print(predictions)
    #print(predicted_labels_corrected)
  

    #acc = np.mean(predictions==y_test)
    accuracy = np.mean(predicted_labels_corrected==y_test)
 
    #print(f"Validation Accuracy: {acc:.2f}")
    print(f"Validation Accuracy prob: {accuracy:.2f}")


    return 0

# %%
knn_fit(df)
# Out:
# Validation Accuracy: 0.72
# Validation Accuracy prob: 0.72
# 0

# %%
def knn_fit(data, trace_length=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=42, stratify=data['identifier']
    )
    
    # Training the classifier
    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    # Prepare test data by identifier
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
 
    test_data.sort_index(inplace=True)

    #print(test_data)
    #print(test_data[test_data['identifier']==46])
    accuracies = []
    
    # Group by identifier and predict for each trajectory
    for identifier, group in test_data.groupby('identifier'):
        # Splitting the group into sub-trajectories
        for start_idx in range(0, len(group), trace_length):
            sub_trajectory = group.iloc[start_idx:start_idx + trace_length]
            #print(sub_trajectory)
            if len(sub_trajectory) < trace_length:
                continue  # Skip the last group if it's smaller than the trace length
            
            # Predict probabilities and determine the most likely class
            probabilities = knn.predict_proba(sub_trajectory[['perturbed_latitude', 'perturbed_longitude']])
            predicted_indices = np.argmax(probabilities, axis=1)
            predicted_labels = knn.classes_[predicted_indices]
            
            # Calculate accuracy for this sub-trajectory
            sub_acc = np.mean(predicted_labels == sub_trajectory['true_labels'].values)
            accuracies.append(sub_acc)
    
    # Overall accuracy
    overall_accuracy = np.mean(accuracies)
    bayes_risk = 1 - overall_accuracy
    print(f"Validation Accuracy for trajectories: {bayes_risk:.2f}")

    return bayes_risk

# Example usage:
# Assuming 'data' is your DataFrame that includes all necessary columns
accuracy = knn_fit(df)
# Out:
# Validation Accuracy for trajectories: 0.22

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=42, stratify=data['identifier']
    )
    
    # Train the classifier
    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            current_features = row[['perturbed_latitude', 'perturbed_longitude']]
            # Reshape the data to ensure it is a 2D array
            if current_features.shape[0] == 1:
                current_features = current_features.values.reshape(1, -1)
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                probabilities /= probabilities.sum(axis=1, keepdims=True)  # Normalize probabilities
            
            predicted_index = np.argmax(probabilities, axis=1)
            predicted_label = knn.classes_[predicted_index][0]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = np.mean(predicted_label == row['true_labels'])
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # Simple transition probabilities model: higher probability for staying at the same location
    transition_matrix = np.ones((len(classes), len(classes))) * 0.1  # Low probability for all transitions
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Higher probability for transitioning to the same or adjacent class indices
    for i in range(len(classes)):
        if previous_predictions[-1] in class_idx_map:
            idx = class_idx_map[previous_predictions[-1]]
            transition_matrix[idx, idx] = 0.5  # High probability to stay at the same location
    
    transition_probs = transition_matrix[class_idx_map[previous_predictions[-1]]]
    transition_probs /= transition_probs.sum()  # Normalize
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=2)
# Out:
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 76
#      73     return transition_probs
#      75 # Example usage assuming 'df' is your DataFrame
# ---> 76 accuracy = knn_predict_with_transition(df, k=2)
#
# Cell In[147], line 36, in knn_predict_with_transition(data, k)
#      33     current_features = current_features.values.reshape(1, -1)
#      35 # Calculate P(o_t|s) using KNN
# ---> 36 probabilities = knn.predict_proba(current_features)
#      38 if previous_predictions:
#      39     # Calculate transition probabilities P(s|previous_predictions)
#      40     transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=42, stratify=data['identifier']
    )
    
    # Train the classifier
    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            current_features = row[['perturbed_latitude', 'perturbed_longitude']].values.reshape(1, -1)  # Ensure 2D shape here
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                probabilities /= probabilities.sum(axis=1, keepdims=True)  # Normalize probabilities
            
            predicted_index = np.argmax(probabilities, axis=1)
            predicted_label = knn.classes_[predicted_index][0]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = np.mean(predicted_label == row['true_labels'])
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # Simple transition probabilities model: higher probability for staying at the same location
    transition_matrix = np.ones((len(classes), len(classes))) * 0.1  # Low probability for all transitions
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Higher probability for transitioning to the same or adjacent class indices
    for i in range(len(classes)):
        if previous_predictions[-1] in class_idx_map:
            idx = class_idx_map[previous_predictions[-1]]
            transition_matrix[idx, idx] = 0.5  # High probability to stay at the same location
    
    transition_probs = transition_matrix[class_idx_map[previous_predictions[-1]]]
    transition_probs /= transition_probs.sum()  # Normalize
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=2)
# Out:
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=42, stratify=data['identifier']
    )
    
    # Train the classifier
    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            current_features = row[['perturbed_latitude', 'perturbed_longitude']].values.reshape(1, -1)  # Ensure 2D shape here
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                probabilities /= probabilities.sum(axis=1, keepdims=True)  # Normalize probabilities
            
            predicted_index = np.argmax(probabilities, axis=1)
            predicted_label = knn.classes_[predicted_index][0]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = np.mean(predicted_label == row['true_labels'])
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # Simple transition probabilities model: higher probability for staying at the same location
    transition_matrix = np.ones((len(classes), len(classes))) * 0.1  # Low probability for all transitions
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Higher probability for transitioning to the same or adjacent class indices
    for i in range(len(classes)):
        if previous_predictions[-1] in class_idx_map:
            idx = class_idx_map[previous_predictions[-1]]
            transition_matrix[idx, idx] = 0.5  # High probability to stay at the same location
    
    transition_probs = transition_matrix[class_idx_map[previous_predictions[-1]]]
    transition_probs /= transition_probs.sum()  # Normalize
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=2)
# Out:
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ss6365\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
df = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\machine_learning\attack1\laplace\200\merged_laplace_0.1_encoded_200.csv')
df = df[0:50000]
df
# Out:
#        longitude   latitude  identifier  perturbed_latitude  \
# 0     -77.680333  43.083838         1.0           43.083840
# 1     -77.680991  43.083803         1.0           43.083827
# 2     -77.681017  43.083802         1.0           43.083831
# 3     -77.681042  43.083802         1.0           43.083767
# 4     -77.681090  43.083802         1.0           43.083803
# ...          ...        ...         ...                 ...
# 49995 -77.674850  43.084315        39.0           43.084250
# 49996 -77.674843  43.084315        39.0           43.084332
# 49997 -77.674836  43.084316        39.0           43.084274
# 49998 -77.674830  43.084315        39.0           43.084298
# 49999 -77.674820  43.084315        39.0           43.084307
#
#        perturbed_longitude  lat_bin  lon_bin  location_id
# 0               -77.680344       97       66        19467
# 1               -77.681023       97       62        19463
# 2               -77.680987       97       62        19463
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)
    features = pd.DataFrame(features_scaled, columns=['perturbed_latitude', 'perturbed_longitude'])
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=42,
    )
    
    # Train the classifier
    k_n = int(math.log(len(X_train)))
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            
            current_features = row[['perturbed_latitude', 'perturbed_longitude']].to_frame().T  # Ensure DataFrame format
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                probabilities /= probabilities.sum(axis=1, keepdims=True)  # Normalize probabilities
            
            predicted_index = np.argmax(probabilities, axis=1)
            predicted_label = knn.classes_[predicted_index][0]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = np.mean(predicted_label == row['true_labels'])
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # Simple transition probabilities model: higher probability for staying at the same location
    transition_matrix = np.ones((len(classes), len(classes))) * 0.1  # Low probability for all transitions
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Higher probability for transitioning to the same or adjacent class indices
    for i in range(len(classes)):
        if previous_predictions[-1] in class_idx_map:
            idx = class_idx_map[previous_predictions[-1]]
            transition_matrix[idx, idx] = 0.5  # High probability to stay at the same location
    
    transition_probs = transition_matrix[class_idx_map[previous_predictions[-1]]]
    transition_probs /= transition_probs.sum()  # Normalize
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=1)
# Out:
# Validation Accuracy for trajectories: 0.74

# %%
accuracy = knn_predict_with_transition(df, k=2)
# Out:
# Validation Accuracy for trajectories: 0.74

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)
    features = pd.DataFrame(features_scaled, columns=['perturbed_latitude', 'perturbed_longitude'])
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=41
    )
    
    # Train the classifier
    k_n = int(math.log(len(X_train)))  # Adjust the number of neighbors based on training size
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            current_features = row[['perturbed_latitude', 'perturbed_longitude']].to_frame().T  # Ensure DataFrame format
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                probabilities /= probabilities.sum(axis=1, keepdims=True)  # Normalize probabilities
            
            predicted_index = np.argmax(probabilities, axis=1)
            predicted_label = knn.classes_[predicted_index][0]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = np.mean(predicted_label == row['true_labels'])
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # More sophisticated transition probabilities model
    transition_matrix = np.ones((len(classes), len(classes))) * 0.1
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Weighted probabilities for transitions
    recent_weight = 0.9  # Higher weight for more recent predictions
    base_weight = (1 - recent_weight) / (k - 1 if k > 1 else 1)  # Distribute the remaining weight

    for pred in reversed(previous_predictions):
        if pred in class_idx_map:
            idx = class_idx_map[pred]
            transition_matrix[:, idx] += base_weight
            base_weight *= (1 - recent_weight) / recent_weight  # Decrease weight for older predictions
    
    # Normalize transition probabilities for the last state
    last_state_index = class_idx_map[previous_predictions[-1]]
    transition_probs = transition_matrix[last_state_index]
    transition_probs /= transition_probs.sum()  # Normalize
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=10)  # Now using a history of 3 for better context
# Out:
# Validation Accuracy for trajectories: 0.79

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import math

def knn_predict_with_transition(data, k=1):
    features = data[['perturbed_latitude', 'perturbed_longitude']]
    labels = data['location_id']

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)
    features = pd.DataFrame(features_scaled, columns=['perturbed_latitude', 'perturbed_longitude'])
    
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.01, random_state=41
    )
    
    # Train the classifier
    k_n = max(int(math.log(len(X_train))), 5)  # Ensure a practical number of neighbors
    knn = KNeighborsClassifier(n_neighbors=k_n, metric='euclidean')
    knn.fit(X_train, y_train)
    
    test_data = X_test.copy()
    test_data['true_labels'] = y_test
    test_data['identifier'] = data.loc[X_test.index, 'identifier']
    accuracies = []
    
    # Predict with transitions
    for identifier, group in test_data.groupby('identifier'):
        previous_predictions = []
        for idx, row in group.iterrows():
            current_features = row[['perturbed_latitude', 'perturbed_longitude']].to_frame().transpose()
            
            # Calculate P(o_t|s) using KNN
            probabilities = knn.predict_proba(current_features)
            
            if previous_predictions:
                # Calculate transition probabilities P(s|previous_predictions)
                transition_probabilities = calculate_transition_probabilities(previous_predictions, k, knn.classes_)
                probabilities *= transition_probabilities
                
                # Normalize probabilities
                if probabilities.sum() > 0:
                    probabilities /= probabilities.sum()
                else:
                    # Handle the case where the sum of probabilities is zero
                    probabilities = np.full(probabilities.shape, 1 / probabilities.shape[1])  # Assign uniform probabilities
            
            predicted_index = np.argmax(probabilities)
            predicted_label = knn.classes_[predicted_index]
            previous_predictions.append(predicted_label)
            
            if len(previous_predictions) > k:
                previous_predictions.pop(0)  # Maintain a buffer of last k predictions
            
            # Calculate accuracy
            sub_acc = (predicted_label == row['true_labels']).astype(float)
            accuracies.append(sub_acc)
    
    overall_accuracy = np.mean(accuracies)
    print(f"Validation Accuracy for trajectories: {overall_accuracy:.2f}")

    return overall_accuracy

def calculate_transition_probabilities(previous_predictions, k, classes):
    # Initialize transition matrix more realistically
    transition_matrix = np.zeros((len(classes), len(classes)))
    class_idx_map = {cls: idx for idx, cls in enumerate(classes)}
    
    # Base weights initialization
    weights = np.geomspace(1, 0.1, num=k)  # Geometric decay for weights
    for i, pred in enumerate(reversed(previous_predictions)):
        if pred in class_idx_map:
            idx = class_idx_map[pred]
            transition_matrix[:, idx] += weights[i]
    
    # Normalize each column to ensure proper probabilities
    transition_matrix = (transition_matrix.T / transition_matrix.sum(axis=1)).T

    # Last state based transition probabilities
    last_state_index = class_idx_map[previous_predictions[-1]]
    transition_probs = transition_matrix[last_state_index, :]
    return transition_probs

# Example usage assuming 'df' is your DataFrame
accuracy = knn_predict_with_transition(df, k=1)
# Out:
# Validation Accuracy for trajectories: 0.06
